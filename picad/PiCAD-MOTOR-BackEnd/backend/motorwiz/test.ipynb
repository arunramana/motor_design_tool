# %%
import configparser

from motorwiz import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import configparser
# ----> 3 from motorwiz import *
#
# File D:\coding\cbeev\motor_design_tool\backend\motorwiz\motorwiz.py:4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 from .trig import *
#       6 from scipy.optimize import fsolve
#       7 import math
#
# ImportError: attempted relative import with no known parent package

# %%
peak_torque = 20
current_limit_i_ph = 115
voltage_limit = 48
r_ag = 41.75
trv = 0.10
ag = 0.5
no_of_poles = 10
no_of_slots = 12
fill_factor = 39
wire_diameter = 0.914
tooth_depth_factor = 0.36
fin_area_factor = 2.9
housing_by_stacklength_ratio = 3.5
heat_transfer_coeff = 31
external_htc = 31
ambient_temperature = 40
magnet = ["N42", "RE"]
steel = ["M350-50A", "IRON"]
wire = ["COPPER", "COPPER"]
topology = ["IPMSM","RADIAL"]
motor_speed_rpm = 2000
motor_torque = 8
assumed_slot_width_ratio = 0.55
assumed_winding_temp = 158

# %%
motor_wiz = MotorWiz(peak_torque, current_limit_i_ph, voltage_limit, r_ag, trv, ag, no_of_poles, no_of_slots, fill_factor, wire_diameter, tooth_depth_factor, fin_area_factor, housing_by_stacklength_ratio, heat_transfer_coeff,external_htc, ambient_temperature ,magnet,steel, wire,topology,motor_speed_rpm, motor_torque, assumed_slot_width_ratio, assumed_winding_temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dcace1503ce6> in <module>
# ----> 1 motor_wiz = MotorWiz(peak_torque, current_limit_i_ph, voltage_limit, r_ag, trv, ag, no_of_poles, no_of_slots, fill_factor, wire_diameter, tooth_depth_factor, fin_area_factor, housing_by_stacklength_ratio, heat_transfer_coeff,external_htc, ambient_temperature ,magnet,steel, wire,topology,motor_speed_rpm, motor_torque, assumed_slot_width_ratio, assumed_winding_temp)
#
# NameError: name 'MotorWiz' is not defined

# %%
motor_wiz.run(motor_speed_rpm,motor_torque)
# Out:
# Motorwiz Inputs
# peak_torque: 20
# current limit: 115.74074074074073
# voltage_limit: 48
# mean airgap radius: 41.75
# TRV: 0.1
# air gap: 0.5
# no. poles: 10
# no. slots: 12
# assumed_slot_width_ratio 0.5462325064108381
# fill factor: 38.31166341532941
# wire dia: 0.914
# tooth_depth_factor: 0.36
# External HTC 31
# fin_area_factor: 2.9
# housing/stack length: 3.5
# ambient_temperature: 40
# assumed_winding_temp: 158
# topology: IPMSM RADIAL
# steel: M350-50A IRON
# magnet: N42 RE
# wire: COPPER COPPER
#
# Calculated Variables:
# Kt (Nm/A_rms) 0.1728
# Ke (V/Krpm) 10.447484337989096
# Max no-load rpm 3248.7366718069834
# Stack length (L) 36.52306055391481
# σ (N/m2) 50000.0
# r = g*W_m*P/[2π*r_g*L_pm] 0.07624188890629716
# Slot pitch p =  2π*r_g/S 21.86024888122898
# Slot opg width W_s = p*w 11.940778537158424
# a = W_s/(2g) 11.940778537158424
# Airgap coeff γ 19.449250077254533
# Carter Coeff K_c = p/(p-γg) 1.801328812161208
# Peak Airgap flux B_g  1.0691644682231736
# ...
